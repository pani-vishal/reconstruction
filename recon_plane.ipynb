# %%
import mitsuba as mi
mi.set_variant('cuda_ad_rgb')
import matplotlib.pyplot as plt
import os

from calibration.helpers.io import *
from calibration.helpers.camera_model import *
from calibration.helpers.linear_alg import *
from mitsuba import ScalarTransform4f as T

import drjit as dr

from ipywidgets import interact

# %% [markdown]
# ## Paths

# %%
folder_dataset = '../datasets/'
folder_params = 'data'
dataset_name = 'unanno36_sorted256_theta_5_70_8_phi_0_360_16'
path_dataset = os.path.join(folder_dataset, dataset_name)
path_params = os.path.join(folder_params, 'npp_' + dataset_name + '.npy')

# %% [markdown]
# ## Functions

# %%
def to_world(dataset, arr_angles, params):
  """ Get to world matrix for a given set of angles """
  arr_to_world = []
  for i, entry in enumerate(dataset):
    angles, wo_measured, vargeo, pg_cam_matrix, ch_ids, ch_corners = entry[0] # No image required
    theta_i, phi_i, theta_o, phi_o = angles

    # filter
    idxs_theta = np.where(arr_angles[:,0] == theta_o)[0]
    idxs_phi = np.where(arr_angles[idxs_theta, 1] == phi_o)[0]
    idxs_var = np.where(arr_angles[idxs_phi, 2] == vargeo)[0]
    if not(len(idxs_theta) and len(idxs_phi) and len(idxs_var)):
      continue
    
    mtx = get_to_world(params, pg_cam_matrix)
    mtx[:3, 3] *= 0.001
    arr_to_world.append(mtx)
  
  return np.array(arr_to_world)

# %% [markdown]
# ## Reconstructing From one View

# %%
def_sample_count = 128
def_res = 2048
path_tex_targ = 'scenes/textures/charuco.png'
path_tex_init = 'scenes/textures/init.png'

def make_simple_scene(path_tex, resx, resy):
  return mi.load_dict({
      'type': 'scene',
      # Integrator
      'integrator': {
        'type': 'prb',
        'max_depth': 16,
      },

      # Sensor
      'sensor': {
        'type': 'perspective',
        'fov_axis': 'x',
        'near_clip': 0.001,
        'far_clip': 100.0,
        'focus_distance': 1000,
        'fov': 39.3077,
        'to_world': T.look_at(
          origin = [0, 0, 1],
          target = [0, 0, 0],
          up = [0, 1, 0]
        ),
        # Sampler
        'sampler': {
          'type': 'independent',
          'sample_count': def_sample_count,
        },
        # Film
        'film': {
          'type': 'hdrfilm',
          'width': resx,
          'height': resy,
          'rfilter': {
            'type': 'tent',
          }
        }
      },

      # BSDFS
      'charuco': {
          'type': 'twosided',
          'material': {
              'type': 'diffuse',
              'reflectance': {
                  'type': 'bitmap',
                  'filename': path_tex,
                  'filter_type': 'bilinear',
              }
          },
      },

      # Light
      'light': {
        'type': 'constant',
        'radiance': {
          'type': 'rgb',
          'value': 1.0,
        }
      },

      # Shapes
      'tex_plane': {
        'type': 'obj',
        'filename': 'scenes/meshes/tex_plane.obj',
        'to_world': T.rotate(axis=[0,1,0], angle=-90),
        'bsdf': {
          'type': 'ref',
          'id': 'charuco',
        },
      }
      
    })

# %%
scene_ref = make_simple_scene(path_tex_targ, def_res, def_res)
scene_opt = make_simple_scene(path_tex_init, def_res, def_res)

# %%
params = mi.traverse(scene_opt)
param_key = 'charuco.brdf_0.reflectance.data'
opt = mi.ad.Adam(lr=0.05)
opt[param_key] = params[param_key]
params.update(opt);

# %%
image_ref = mi.render(scene_ref, spp=4)

plt.figure(figsize=(7.5,7.5))
plt.axis('off')
plt.imshow(image_ref ** (1.0 / 2.2));
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %%
def mse(image):
    return dr.mean(dr.sqr(image - image_ref))

# %%
iteration_count = 50

errors = []
for it in range(iteration_count):
    # Perform a (noisy) differentiable rendering of the scene
    image = mi.render(scene_opt, params, seed=it, spp=1)
    
    # Evaluate the objective function from the current rendered image
    loss = mse(image)

    # Backpropagate through the rendering process
    dr.backward(loss)

    # Optimizer: take a gradient descent step
    opt.step()

    # Post-process the optimized parameters to ensure legal color values.
    opt[param_key] = dr.clamp(opt[param_key], 0.0, 1.0)

    # Update the scene state to the new optimized values
    params.update(opt)
    
    # Display loss
    print(f"Iteration {it:02d}: parameter error = {loss[0]:6f}", end='\r')
    errors.append(loss)
print('\nOptimization complete.')
# Out:
# Iteration 30: parameter error = 0.050771
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /home/vpani/rgl/recon/recon_plane.ipynb Cell 12 in <cell line: 4>()
#       <a href='vscode-notebook-cell:/home/vpani/rgl/recon/recon_plane.ipynb#X14sZmlsZQ%3D%3D?line=8'>9</a> loss = mse(image)
#      <a href='vscode-notebook-cell:/home/vpani/rgl/recon/recon_plane.ipynb#X14sZmlsZQ%3D%3D?line=10'>11</a> # Backpropagate through the rendering process
# ---> <a href='vscode-notebook-cell:/home/vpani/rgl/recon/recon_plane.ipynb#X14sZmlsZQ%3D%3D?line=11'>12</a> dr.backward(loss)
#      <a href='vscode-notebook-cell:/home/vpani/rgl/recon/recon_plane.ipynb#X14sZmlsZQ%3D%3D?line=13'>14</a> # Optimizer: take a gradient descent step
#      <a href='vscode-notebook-cell:/home/vpani/rgl/recon/recon_plane.ipynb#X14sZmlsZQ%3D%3D?line=14'>15</a> opt.step()
#
# File ~/rgl/mitsuba3/build/python/drjit/router.py:4519, in backward(arg, flags)
#    4504 def backward(arg, flags=_dr.ADFlag.Default):
#    4505     '''
#    4506     Backward propagate gradients from a provided Dr.Jit differentiable array.
#    4507
#    (...)
#    4517           destructed during the traversal. The default value is ``ADFlag.Default``.
#    4518     '''
# -> 4519     backward_from(arg, flags)
#
# File ~/rgl/mitsuba3/build/python/drjit/router.py:4465, in backward_from(arg, flags)
#    4463 set_grad(arg, 1)
#    4464 enqueue(_dr.ADMode.Backward, arg)
# -> 4465 traverse(ta, _dr.ADMode.Backward, flags)
#
# File ~/rgl/mitsuba3/build/python/drjit/router.py:4346, in traverse(dtype, mode, flags)
#    4343 if not _dr.is_diff_v(dtype):
#    4344     raise Exception('traverse(): expected a differentiable array type!')
# -> 4346 dtype.traverse_(mode, flags)
#
# File ~/rgl/mitsuba3/build/python/mitsuba/python/util.py:389, in _RenderOp.backward(self)
#     384 if not isinstance(self.params, mi.SceneParameters):
#     385     raise Exception('An instance of mi.SceneParameter containing the '
#     386                     'scene parameter to be differentiated should be '
#     387                     'provided to mi.render() if backward derivatives are '
#     388                     'desired!')
# --> 389 self.integrator.render_backward(self.scene, self.params, self.grad_out(),
#     390                                 self.sensor, self.seed[1], self.spp[1])
#
# File ~/rgl/mitsuba3/build/python/mitsuba/python/ad/integrators/common.py:930, in RBIntegrator.render_backward(self, scene, params, grad_in, sensor, seed, spp)
#     926 # Probably a little overkill, but why not.. If there are any
#     927 # DrJit arrays to be collected by Python's cyclic GC, then
#     928 # freeing them may enable loop simplifications in dr.eval().
#     929 del valid
# --> 930 gc.collect()
#     932 # This step launches a kernel
#     933 dr.schedule(state_out, block.tensor())
#
# KeyboardInterrupt:

# %%
image_final = mi.render(scene_opt, spp=2)

plt.figure(figsize=(15,15))
plt.axis('off')
plt.imshow(image_final);
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %%
plt.plot(errors);

# %% [markdown]
# ## Reconstructing from 2 views

# %%
def_sample_count = 128
def_res_x = 6576
def_res_y = 4384
path_tex_targ = 'scenes/textures/charuco.png'
path_tex_init = 'scenes/textures/init.png'

def make_batch_scene(path_tex, resx, resy):
  sensors = mi.load_dict({
    'type': 'batch',
    'camera_0': {
      'type': 'perspective',
      'fov_axis': 'x',
      'near_clip': 0.001,
      'far_clip': 100.0,
      'focus_distance': 1000,
      'fov': 39.3077,
      'to_world': T.look_at(
        origin = [0, 1, 1],
        target = [0, 0, 0],
        up = [0, 1, 0]
      ),
    },
    # 'camera_1': {
    #   'type': 'perspective',
    #   'fov_axis': 'x',
    #   'near_clip': 0.001,
    #   'far_clip': 100.0,
    #   'focus_distance': 1000,
    #   'fov': 39.3077,
    #   'to_world': T.look_at(
    #     origin = [0, -1, 1],
    #     target = [0, 0, 0],
    #     up = [0, 1, 0]
    #   ),
    # },
    # Sampler
    'sampler': {
      'type': 'independent',
      'sample_count': def_sample_count,
    },
    # Film
    'film': {
      'type': 'hdrfilm',
      # Change the film size to match the batch size
      'width': resx,
      'height': resy,
      'rfilter': {
        'type': 'tent',
      }
    }
  })

  scene =  mi.load_dict({
    'type': 'scene',
    # Integrator
    'integrator': {
      'type': 'prb',
      'max_depth': 16,
    },

    # Sensor
    'sensors': sensors, 

    # BSDFS
    'charuco': {
        'type': 'twosided',
        'material': {
            'type': 'diffuse',
            'reflectance': {
                'type': 'bitmap',
                'filename': path_tex,
                'filter_type': 'bilinear',
            }
        },
    },

    # Light
    'light': {
      'type': 'constant',
      'radiance': {
        'type': 'rgb',
        'value': 1.0,
      }
    },

    # Shapes
    'tex_plane': {
      'type': 'obj',
      'filename': 'scenes/meshes/tex_plane.obj',
      'to_world': T.rotate(axis=[0,1,0], angle=-90),
      'bsdf': {
        'type': 'ref',
        'id': 'charuco',
      },
    }
  })

  return scene

# %%
scene_ref = make_batch_scene(path_tex_targ, def_res_x, def_res_y)
scene_opt = make_batch_scene(path_tex_init, def_res_x, def_res_y)

# %%
params = mi.traverse(scene_opt)
param_key = 'charuco.brdf_0.reflectance.data'
opt = mi.ad.Adam(lr=0.5)
opt[param_key] = params[param_key]
params.update(opt);

# %%
ref_img = mi.render(scene_ref, spp=4)

# %%
plt.figure(figsize=(15,15))
plt.axis('off')
plt.imshow(ref_img);
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %%
iteration_count = 50
errors = []
for it in range(iteration_count):
    # Perform a (noisy) differentiable rendering of the scene
    image = mi.render(scene_opt, params, seed=it, spp=1)
    
    # Evaluate the objective function from the current rendered image
    loss = dr.mean(dr.sqr(image - ref_img))

    # Backpropagate through the rendering process
    dr.backward(loss)

    # Optimizer: take a gradient descent step
    opt.step()

    # Post-process the optimized parameters to ensure legal color values.
    opt[param_key] = dr.clamp(opt[param_key], 0.0, 1.0)

    # Update the scene state to the new optimized values
    params.update(opt)
    
    # Display loss
    print(f"Iteration {it:02d}: parameter error = {loss[0]:6f}", end='\r')
    errors.append(loss)
print('\nOptimization complete.')
# Out:
# Iteration 03: parameter error = 0.031947
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In [13], line 20
#      17 opt[param_key] = dr.clamp(opt[param_key], 0.0, 1.0)
#      19 # Update the scene state to the new optimized values
# ---> 20 params.update(opt)
#      22 # Display loss
#      23 print(f"Iteration {it:02d}: parameter error = {loss[0]:6f}", end='\r')
#
# File ~/rgl/mitsuba3/build/python/mitsuba/python/util.py:212, in SceneParameters.update(self, values)
#     210 out = []
#     211 for _, node, keys in work_list:
# --> 212     node.parameters_changed(list(keys))
#     213     out.append((node, keys))
#     215 self.nodes_to_update.clear()
#
# KeyboardInterrupt:

# %%
image_final = mi.render(scene_opt, spp=2)

plt.figure(figsize=(30,15))
plt.axis('off')
plt.imshow(image_final);
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %%
plt.figure(figsize=(30,15))
plt.axis('off')
plt.imshow(ref_img);
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %% [markdown]
# ## Reconstructing from 2 Captures

# %%
def tfm_plane(params):
  ij_to_sample = rot_scipy(params[:3])
  ij_to_sample[0:3, 3] = params[3:6] * 0.001
  return T(ij_to_sample) @ T.translate([.31/2, .18/2, 0])

# %% [markdown]
# ### Reconstruction

# %%
dataset = read_dataset(path_dataset, 64, v=True)
params_cam = load_params(path_params, v=True)
# Out:
# Reading ../datasets/unanno36_sorted256_theta_5_70_8_phi_0_360_16: 100%|██████████| 64/64 [00:18<00:00,  3.38it/s]
# ====================
#
# Loaded parameters from data/npp_unanno36_sorted256_theta_5_70_8_phi_0_360_16.npy
# ********************

# %%
thetas_uniq, phis_uniq, vars_uniq = get_dataset_angles(dataset)
print("Available angles")
print(thetas_uniq, phis_uniq, vars_uniq)
# Out:
# Available angles
# [ 5 14 23 32 42 51 60 70] [  0  22  45  67  90 112 135 157 180 202 225 247 270 292 315 337] [0 1]

# %%
# [[theta1, phi1, var1], [theta2, phi2, var2]]
arr_angles = np.array([
  [51, 0, 0],
  [70, 337, 0]
])

arr_to_worlds = to_world(dataset, arr_angles, params_cam)
mtx_plane = tfm_plane(params_cam)

# %%
mtx_plane
# Out:
# [[0.999955, -0.00948635, -0.000619036, 0.00502612],
#  [0.00948619, 0.999955, -0.000266704, -0.000541724],
#  [0.000621538, 0.000260819, 1, -0.00106889],
#  [0, 0, 0, 1]]

# %%
def_sample_count = 128
def_res_x = 6576 // 2
def_res_y = 4384 // 2
path_tex_targ = 'scenes/textures/charuco.png'
path_tex_init = 'scenes/textures/init.png'

def make_board_scene(path_tex, resx, resy, mtx_plane, arr_to_worlds):
  sensors = mi.load_dict({
    'type': 'batch',
    'camera_0': {
      'type': 'perspective',
      'fov_axis': 'x',
      'near_clip': 0.001,
      'far_clip': 1000.0,
      'fov': 12.476723279540094 * 1.5,
      'to_world': T(arr_to_worlds[0]),
    },
    'camera_1': {
      'type': 'perspective',
      'fov_axis': 'x',
      'near_clip': 0.001,
      'far_clip': 100.0,
      'fov': 12.476723279540094 * 1.5,
      'to_world': T(arr_to_worlds[1]),
    },
    # Sampler
    'sampler': {
      'type': 'independent',
      'sample_count': def_sample_count,
    },
    # Film
    'film': {
      'type': 'hdrfilm',
      # Change the film size to match the batch size
      'width': 2 * resx,
      'height': resy,
      'rfilter': {
        'type': 'tent',
      }
    }
  })

  scene =  mi.load_dict({
    'type': 'scene',
    # Integrator
    'integrator': {
      'type': 'prb',
      'max_depth': 8,
    },

    # Sensor
    'sensors': sensors, 

    # BSDFS
    'charuco': {
        'type': 'twosided',
        'material': {
            'type': 'diffuse',
            'reflectance': {
                'type': 'bitmap',
                'filename': path_tex,
                'filter_type': 'bilinear',
            }
        },
    },

    # Light
    'light': {
      'type': 'constant',
      'radiance': {
        'type': 'rgb',
        'value': 1.0,
      }
    },

    # Shapes
    'tex_plane': {
      'type': 'obj',
      'filename': 'scenes/meshes/tex_plane.obj',
      'to_world': T(mtx_plane) @ T.rotate(axis=[0,1,0], angle=-90),
      'bsdf': {
        'type': 'ref',
        'id': 'charuco',
      },
    }
  })

  return scene

# %%
scene_opt = make_board_scene(path_tex_init, def_res_x, def_res_y, mtx_plane, arr_to_worlds)

# %%
## Read Images
ref_img_0 = mi.TensorXf(mi.Bitmap('0_0_70_337_0.png').convert(mi.Bitmap.PixelFormat.RGB, mi.Struct.Type.Float32).resample([def_res_x, def_res_y]))
ref_img_1 = mi.TensorXf(mi.Bitmap('0_0_51_0_0.png').convert(mi.Bitmap.PixelFormat.RGB, mi.Struct.Type.Float32).resample([def_res_x, def_res_y]))
ref_img = mi.TensorXf(np.hstack((ref_img_0, ref_img_1)))

# %%
# ref_img = ref_img_0

# %%
params = mi.traverse(scene_opt)
param_key = 'charuco.brdf_0.reflectance.data'
opt = mi.ad.Adam(lr=0.1)
opt[param_key] = params[param_key]
params.update(opt);

# %%
init_img = mi.render(scene_opt, spp=4)

# %%
plt.figure(figsize=(15,15))
plt.axis('off')
plt.imshow(init_img);
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %%
iteration_count = 100
errors = []
for it in range(iteration_count):
    # Perform a (noisy) differentiable rendering of the scene
    image = mi.render(scene_opt, params, seed=it, spp=1)
    
    # Evaluate the objective function from the current rendered image
    loss = dr.mean(dr.sqr(image - ref_img))

    # Backpropagate through the rendering process
    dr.backward(loss)

    # Optimizer: take a gradient descent step
    opt.step()

    # Post-process the optimized parameters to ensure legal color values.
    opt[param_key] = dr.clamp(opt[param_key], 0.0, 1.0)

    # Update the scene state to the new optimized values
    params.update(opt)
    
    # Display loss
    print(f"Iteration {it:02d}: parameter error = {loss[0]:6f}", end='\r')
    errors.append(loss)
print('\nOptimization complete.')
# Out:
# Iteration 99: parameter error = 0.497823
# Optimization complete.

# %%
params_ref_bm = mi.util.convert_to_bitmap(params[param_key]).convert(mi.Bitmap.PixelFormat.RGB,
                                                              mi.Struct.Type.UInt8, False)

# %%
mi.util.write_bitmap(f'recon_tex.png', params_ref_bm, write_async=True)

# %%
image_final = mi.render(scene_opt, spp=16)
mi.util.write_bitmap(f'final_image.png', image_final, write_async=True)

# %%
mi.util.write_bitmap('ref_image.png', ref_img, write_async=True)
# Out:
# The Kernel crashed while executing code in the the current cell or a previous cell. Please review the code in the cell(s) to identify a possible cause of the failure. Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info. View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %% [markdown]
# ## Scratch

# %% [markdown]
# ### cbox python dict

# %%
def_sample_count = 128
def_res = 512
path_tex = 'scenes/textures/charuco.png'

scene = mi.load_dict({
    'type': 'scene',

    # Integrator
    'integrator': {
        'type': 'path',
        'max_depth': 8
    },
    # Sensor
    'sensor': {
        'type': 'perspective',
        'fov_axis': 'x',
        'near_clip': 0.001,
        'far_clip': 100.0,
        'focus_distance': 1000,
        'fov': 39.3077,
        'to_world': T.look_at(
            origin = [0, 0, 4],
            target = [0, 0, 0],
            up = [0, 1, 0]
        ),
        # Sampler
        'sampler': {
            'type': 'independent',
            'sample_count': def_sample_count,
        },
        # Film
        'film': {
            'type': 'hdrfilm',
            'width': def_res,
            'height': def_res,
            'rfilter': {
                'type': 'tent',
            }
        }
    },
    # BSDFs
    'gray': {
        'type': 'diffuse',
        'reflectance': {
            'type': 'rgb',
            'value': [0.85, 0.85, 0.85],
        }
    },
    'white': {
        'type': 'diffuse',
        'reflectance': {
            'type': 'rgb',
            'value': [0.885809, 0.698859, 0.666422],
        }
    },
    'green': {
        'type': 'diffuse',
        'reflectance': {
            'type': 'rgb',
            'value': [0.105421, 0.37798, 0.076425],
        }
    },
    'red': {
        'type': 'diffuse',
        'reflectance': {
            'type': 'rgb',
            'value': [0.570068, 0.0430135, 0.0443706],
        },
    },
    'charuco': {
        'type': 'twosided',
        'material': {
            'type': 'diffuse',
            'reflectance': {
                'type': 'bitmap',
                'filename': path_tex,
                'filter_type': 'bilinear'
            }
        }
    },
    # Light
    'light': {
        'type': 'obj',
        'filename': 'scenes/meshes/cbox_luminaire.obj',
        'to_world': T.translate([0.0, -0.01, 0.3]),
        'bsdf': {
            'type': 'ref',
            'id': 'white',
        },
        'ceiling': {
            'type': 'area',
            'radiance': {
                'type': 'rgb',
                'value': [10, 10, 10],
            }
        }
    },
    # Shapes
    'floor': {
        'type': 'obj',
        'filename': 'scenes/meshes/cbox_floor.obj',
        'bsdf': {
            'type': 'ref',
            'id': 'white',
        },
    },
    'ceiling': {
        'type': 'obj',
        'filename': 'scenes/meshes/cbox_ceiling.obj',
        'bsdf': {
            'type': 'ref',
            'id': 'white',
        },
    },
    'back': {
        'type': 'obj',
        'filename': 'scenes/meshes/cbox_back.obj',
        'bsdf': {
            'type': 'ref',
            'id': 'white',
        },
    },
    'greenwall': {
        'type': 'obj',
        'filename': 'scenes/meshes/cbox_greenwall.obj',
        'bsdf': {
            'type': 'ref',
            'id': 'green',
        },
    },
    'redwall': {
        'type': 'obj',
        'filename': 'scenes/meshes/cbox_redwall.obj',
        'bsdf': {
            'type': 'ref',
            'id': 'red',
        },  
    },
    'tex_plane': {
        'type': 'obj',
        'filename': 'scenes/meshes/tex_plane.obj',
        'to_world': T.rotate(axis=[0,1,0], angle=-90),
        'bsdf': {
            'type': 'ref',
            'id': 'charuco',
        },
    }

})

# %%
# scene = mi.load_file("scenes/cbox.xml")
original_image = mi.render(scene, spp=128)

plt.figure(figsize=(15,15))
plt.axis('off')
plt.imshow(original_image ** (1.0 / 2.2));
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %%
scene = mi.load_file("scenes/cbox.xml")
original_image = mi.render(scene, spp=128)

plt.figure(figsize=(15,15))
plt.axis('off')
plt.imshow(original_image ** (1.0 / 2.2));
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %%
a = np.array([[1, 2], [3, 4], [1, 3], [5, 6]])
idxs_theta = np.where(a[:,0]==1)[0]
idxs_phi = np.where(a[idxs_theta]==2)[0]
len(idxs_theta) and len(idxs_phi)
# Out:
# 1

# %%
mi.Transform4f.perspective()
